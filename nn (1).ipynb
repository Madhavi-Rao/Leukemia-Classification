# %%
# !pip install tensorflow==2.9.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow==2.9.1 in c:\users\madhavi s rao\appdata\roaming\python\python39\site-packages (2.9.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (14.0.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (1.51.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\madhavi s rao\appdata\roaming\python\python39\site-packages (from tensorflow==2.9.1) (2.9.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\madhavi s rao\appdata\roaming\python\python39\site-packages (from tensorflow==2.9.1) (2.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (3.3.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (0.29.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (1.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (2.2.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (63.4.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\madhavi s rao\appdata\roaming\python\python39\site-packages (from tensorflow==2.9.1) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (4.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (1.21.5)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\madhavi s rao\appdata\roaming\python\python39\site-packages (from tensorflow==2.9.1) (1.12)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.9.1) (3.7.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.9.1) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorflow==2.9.1) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (5.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.2.2)

# %%
# import system libs
import os
import time
import shutil
import pathlib
import itertools

# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %%
# Generate data paths with labels
data_dir = 'C:/Users/Madhavi S Rao/Downloads/dataset/training_set'
filepaths = []
labels = []

folds = os.listdir(data_dir)
for fold in folds:
    foldpath = os.path.join(data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        filepaths.append(fpath)
        labels.append(fold)

# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis= 1)

# %%
df
# Out:
#                                                filepaths labels
# 0      C:/Users/Madhavi S Rao/Downloads/dataset/train...    all
# 1      C:/Users/Madhavi S Rao/Downloads/dataset/train...    all
# 2      C:/Users/Madhavi S Rao/Downloads/dataset/train...    all
# 3      C:/Users/Madhavi S Rao/Downloads/dataset/train...    all
# 4      C:/Users/Madhavi S Rao/Downloads/dataset/train...    all
# ...                                                  ...    ...
# 10656  C:/Users/Madhavi S Rao/Downloads/dataset/train...    hem
# 10657  C:/Users/Madhavi S Rao/Downloads/dataset/train...    hem
# 10658  C:/Users/Madhavi S Rao/Downloads/dataset/train...    hem
# 10659  C:/Users/Madhavi S Rao/Downloads/dataset/train...    hem
# 10660  C:/Users/Madhavi S Rao/Downloads/dataset/train...    hem
#
# [10661 rows x 2 columns]

# %%
# train dataframe
train_df, dummy_df = train_test_split(df,  train_size= 0.7, shuffle= True, random_state= 123)

# valid and test dataframe
valid_df, test_df = train_test_split(dummy_df,  train_size= 0.5, shuffle= True, random_state= 123)

# %%
# crobed image size
batch_size = 16
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

# Recommended : use custom function for test data batch size, else we can use normal batch size.
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

# This function which will be used in image data generator for data augmentation, it just take the image and return it again.
def scalar(img):
    return img

tr_gen = ImageDataGenerator(preprocessing_function= scalar)
ts_gen = ImageDataGenerator(preprocessing_function= scalar)

train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

# Note: we will use custom test_batch_size, and make shuffle= false
test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size= test_batch_size)
# Out:
# Found 7462 validated image filenames belonging to 2 classes.
# Found 1599 validated image filenames belonging to 2 classes.
# Found 1600 validated image filenames belonging to 2 classes.

# %%
g_dict = train_gen.class_indices      # defines dictionary {'class': index}
classes = list(g_dict.keys())       # defines list of dictionary's kays (classes), classes names : string
images, labels = next(train_gen)      # get a batch size samples from the generator

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       # scales data to range (0 - 255)
    plt.imshow(image)
    index = np.argmax(labels[i])  # get image index
    class_name = classes[index]   # get class of image
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
plt.show()

# %%
# Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
class_count = len(list(train_gen.class_indices.keys())) # to define number of classes in dense layer

# create pre-trained model (you can built on pretrained model such as :  efficientnet, VGG , Resnet )
# we will use efficientnetb3 from EfficientNet family.
base_model = tf.keras.applications.efficientnet. (include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
# base_model.trainable = False

model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])

model.compile(Adam(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
filepath="leukemia.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=2, save_best_only=True, mode='min',patience=5)
callbacks_list = [checkpoint]

# %%
batch_size = 16   # set batch size for training
epochs = 60   # number of all epochs in training

history = model.fit(x= train_gen, epochs= epochs, verbose= 1, validation_data= valid_gen, 
                    validation_steps= None, shuffle= False,callbacks=callbacks_list)
# Out:
# Epoch 1/60
# 467/467 [==============================] - ETA: 0s - loss: 2.6379 - accuracy: 0.8145
# Epoch 1: val_loss improved from inf to 0.78310, saving model to leukemia.hdf5
# 467/467 [==============================] - 919s 2s/step - loss: 2.6379 - accuracy: 0.8145 - val_loss: 0.7831 - val_accuracy: 0.8499
# Epoch 2/60
# 467/467 [==============================] - ETA: 0s - loss: 0.6017 - accuracy: 0.8596
# Epoch 2: val_loss improved from 0.78310 to 0.55610, saving model to leukemia.hdf5
# 467/467 [==============================] - 911s 2s/step - loss: 0.6017 - accuracy: 0.8596 - val_loss: 0.5561 - val_accuracy: 0.8549
# Epoch 3/60
# 467/467 [==============================] - ETA: 0s - loss: 0.4519 - accuracy: 0.8763
# Epoch 3: val_loss improved from 0.55610 to 0.52286, saving model to leukemia.hdf5
# 467/467 [==============================] - 1050s 2s/step - loss: 0.4519 - accuracy: 0.8763 - val_loss: 0.5229 - val_accuracy: 0.8218
# Epoch 4/60
# 467/467 [==============================] - ETA: 0s - loss: 0.4352 - accuracy: 0.8854
# Epoch 4: val_loss did not improve from 0.52286
# 467/467 [==============================] - 929s 2s/step - loss: 0.4352 - accuracy: 0.8854 - val_loss: 0.6928 - val_accuracy: 0.6986
# Epoch 5/60
# 467/467 [==============================] - ETA: 0s - loss: 0.4139 - accuracy: 0.8905
# Epoch 5: val_loss did not improve from 0.52286
# 467/467 [==============================] - 917s 2s/step - loss: 0.4139 - accuracy: 0.8905 - val_loss: 0.5472 - val_accuracy: 0.8693
# Epoch 6/60
# 467/467 [==============================] - ETA: 0s - loss: 0.4006 - accuracy: 0.8973
# Epoch 6: val_loss improved from 0.52286 to 0.43132, saving model to leukemia.hdf5
# 467/467 [==============================] - 908s 2s/step - loss: 0.4006 - accuracy: 0.8973 - val_loss: 0.4313 - val_accuracy: 0.8637
# Epoch 7/60
# 467/467 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.9164
# Epoch 7: val_loss did not improve from 0.43132
# 467/467 [==============================] - 941s 2s/step - loss: 0.3294 - accuracy: 0.9164 - val_loss: 0.4754 - val_accuracy: 0.8530
# Epoch 8/60
# 467/467 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.9283
# Epoch 8: val_loss improved from 0.43132 to 0.43014, saving model to leukemia.hdf5
# 467/467 [==============================] - 1015s 2s/step - loss: 0.3029 - accuracy: 0.9283 - val_loss: 0.4301 - val_accuracy: 0.8906
# Epoch 9/60
# 467/467 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.9272
# Epoch 9: val_loss improved from 0.43014 to 0.34096, saving model to leukemia.hdf5
# 467/467 [==============================] - 1013s 2s/step - loss: 0.2947 - accuracy: 0.9272 - val_loss: 0.3410 - val_accuracy: 0.9137
# Epoch 10/60
# 467/467 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.9363
# Epoch 10: val_loss did not improve from 0.34096
# 467/467 [==============================] - 1020s 2s/step - loss: 0.2723 - accuracy: 0.9363 - val_loss: 0.4964 - val_accuracy: 0.8655
# Epoch 11/60
# 467/467 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.9410
# Epoch 11: val_loss improved from 0.34096 to 0.29430, saving model to leukemia.hdf5
# 467/467 [==============================] - 1711s 4s/step - loss: 0.2613 - accuracy: 0.9410 - val_loss: 0.2943 - val_accuracy: 0.9062
# Epoch 12/60
# 467/467 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9449
# Epoch 12: val_loss improved from 0.29430 to 0.27845, saving model to leukemia.hdf5
# 467/467 [==============================] - 836s 2s/step - loss: 0.2379 - accuracy: 0.9449 - val_loss: 0.2784 - val_accuracy: 0.9262
# Epoch 13/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9550
# Epoch 13: val_loss did not improve from 0.27845
# 467/467 [==============================] - 1106s 2s/step - loss: 0.1966 - accuracy: 0.9550 - val_loss: 0.2972 - val_accuracy: 0.9049
# Epoch 14/60
# 467/467 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9562
# Epoch 14: val_loss did not improve from 0.27845
# 467/467 [==============================] - 1055s 2s/step - loss: 0.2193 - accuracy: 0.9562 - val_loss: 0.2975 - val_accuracy: 0.9393
# Epoch 15/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1736 - accuracy: 0.9682
# Epoch 15: val_loss did not improve from 0.27845
# 467/467 [==============================] - 1081s 2s/step - loss: 0.1736 - accuracy: 0.9682 - val_loss: 0.3019 - val_accuracy: 0.9156
# Epoch 16/60
# 467/467 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9465
# Epoch 16: val_loss improved from 0.27845 to 0.23555, saving model to leukemia.hdf5
# 467/467 [==============================] - 1102s 2s/step - loss: 0.2384 - accuracy: 0.9465 - val_loss: 0.2355 - val_accuracy: 0.9362
# Epoch 17/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9692
# Epoch 17: val_loss did not improve from 0.23555
# 467/467 [==============================] - 1075s 2s/step - loss: 0.1678 - accuracy: 0.9692 - val_loss: 0.2745 - val_accuracy: 0.9375
# Epoch 18/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9711
# Epoch 18: val_loss did not improve from 0.23555
# 467/467 [==============================] - 991s 2s/step - loss: 0.1651 - accuracy: 0.9711 - val_loss: 0.2760 - val_accuracy: 0.9143
# Epoch 19/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9732
# Epoch 19: val_loss did not improve from 0.23555
# 467/467 [==============================] - 1063s 2s/step - loss: 0.1573 - accuracy: 0.9732 - val_loss: 0.6181 - val_accuracy: 0.8368
# Epoch 20/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9763
# Epoch 20: val_loss did not improve from 0.23555
# 467/467 [==============================] - 11583s 25s/step - loss: 0.1416 - accuracy: 0.9763 - val_loss: 3.4382 - val_accuracy: 0.3164
# Epoch 21/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9681
# Epoch 21: val_loss did not improve from 0.23555
# 467/467 [==============================] - 1328s 3s/step - loss: 0.1651 - accuracy: 0.9681 - val_loss: 0.3269 - val_accuracy: 0.9243
# Epoch 22/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9753
# Epoch 45/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9934
# Epoch 45: val_loss did not improve from 0.21214
# 467/467 [==============================] - 970s 2s/step - loss: 0.0539 - accuracy: 0.9934 - val_loss: 0.8552 - val_accuracy: 0.8324
# Epoch 46/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9958
# Epoch 46: val_loss did not improve from 0.21214
# 467/467 [==============================] - 998s 2s/step - loss: 0.0450 - accuracy: 0.9958 - val_loss: 0.2505 - val_accuracy: 0.9387
# Epoch 47/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9940
# Epoch 47: val_loss did not improve from 0.21214
# 467/467 [==============================] - 1031s 2s/step - loss: 0.0520 - accuracy: 0.9940 - val_loss: 0.2375 - val_accuracy: 0.9350
# Epoch 48/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9909
# Epoch 48: val_loss did not improve from 0.21214
# 467/467 [==============================] - 1004s 2s/step - loss: 0.0659 - accuracy: 0.9909 - val_loss: 0.5750 - val_accuracy: 0.8587
# Epoch 49/60
# 467/467 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9849
# Epoch 49: val_loss did not improve from 0.21214
# 467/467 [==============================] - 1030s 2s/step - loss: 0.1068 - accuracy: 0.9849 - val_loss: 0.2820 - val_accuracy: 0.9431
# Epoch 50/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9882
# Epoch 50: val_loss improved from 0.21214 to 0.20001, saving model to leukemia.hdf5
# 467/467 [==============================] - 906s 2s/step - loss: 0.0823 - accuracy: 0.9882 - val_loss: 0.2000 - val_accuracy: 0.9493
# Epoch 51/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9925
# Epoch 51: val_loss did not improve from 0.20001
# 467/467 [==============================] - 1177s 3s/step - loss: 0.0510 - accuracy: 0.9925 - val_loss: 1.3775 - val_accuracy: 0.8074
# Epoch 52/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9890
# Epoch 52: val_loss did not improve from 0.20001
# 467/467 [==============================] - 890s 2s/step - loss: 0.0799 - accuracy: 0.9890 - val_loss: 0.2849 - val_accuracy: 0.9231
# Epoch 53/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9932
# Epoch 53: val_loss did not improve from 0.20001
# 467/467 [==============================] - 850s 2s/step - loss: 0.0558 - accuracy: 0.9932 - val_loss: 0.2698 - val_accuracy: 0.9231
# Epoch 54/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9934
# Epoch 54: val_loss did not improve from 0.20001
# 467/467 [==============================] - 851s 2s/step - loss: 0.0478 - accuracy: 0.9934 - val_loss: 0.2967 - val_accuracy: 0.9368
# Epoch 55/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9977
# Epoch 55: val_loss did not improve from 0.20001
# 467/467 [==============================] - 968s 2s/step - loss: 0.0314 - accuracy: 0.9977 - val_loss: 0.3166 - val_accuracy: 0.9281
# Epoch 56/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9920
# Epoch 56: val_loss improved from 0.20001 to 0.19658, saving model to leukemia.hdf5
# 467/467 [==============================] - 915s 2s/step - loss: 0.0511 - accuracy: 0.9920 - val_loss: 0.1966 - val_accuracy: 0.9412
# Epoch 57/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9875
# Epoch 57: val_loss did not improve from 0.19658
# 467/467 [==============================] - 911s 2s/step - loss: 0.0764 - accuracy: 0.9875 - val_loss: 0.4038 - val_accuracy: 0.8912
# Epoch 58/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9934
# Epoch 58: val_loss did not improve from 0.19658
# 467/467 [==============================] - 920s 2s/step - loss: 0.0467 - accuracy: 0.9934 - val_loss: 1.4250 - val_accuracy: 0.6160
# Epoch 59/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9946
# Epoch 59: val_loss did not improve from 0.19658
# 467/467 [==============================] - 906s 2s/step - loss: 0.0434 - accuracy: 0.9946 - val_loss: 0.2086 - val_accuracy: 0.9412
# Epoch 60/60
# 467/467 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9961
# Epoch 60: val_loss did not improve from 0.19658
# 467/467 [==============================] - 919s 2s/step - loss: 0.0346 - accuracy: 0.9961 - val_loss: 0.2153 - val_accuracy: 0.9525

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 20/20 [==============================] - 6s 319ms/step - loss: 0.0297 - accuracy: 0.9969
# 20/20 [==============================] - 6s 323ms/step - loss: 0.1959 - accuracy: 0.9563
# 20/20 [==============================] - 37s 2s/step - loss: 0.2671 - accuracy: 0.9400
# Train Loss:  0.029712367802858353
# Train Accuracy:  0.996874988079071
# --------------------
# Validation Loss:  0.1958627998828888
# Validation Accuracy:  0.956250011920929
# --------------------
# Test Loss:  0.26708611845970154
# Test Accuracy:  0.9399999976158142

# %%
preds = model.predict_generator(test_gen)
y_pred = np.argmax(preds, axis=1)

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize= (5, 5))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
# Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#          all       0.92      0.99      0.96      1082
#          hem       0.98      0.83      0.90       518
#
#     accuracy                           0.94      1600
#    macro avg       0.95      0.91      0.93      1600
# weighted avg       0.94      0.94      0.94      1600

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0768 - accuracy: 0.9969
# 20/20 [==============================] - 8s 399ms/step - loss: 0.3270 - accuracy: 0.9281
# 20/20 [==============================] - 42s 2s/step - loss: 0.2690 - accuracy: 0.9456
# Train Loss:  0.07676209509372711
# Train Accuracy:  0.996874988079071
# --------------------
# Validation Loss:  0.3269581198692322
# Validation Accuracy:  0.9281250238418579
# --------------------
# Test Loss:  0.2689920663833618
# Test Accuracy:  0.9456250071525574

# %%
preds = model.predict_generator(test_gen)
y_pred = np.argmax(preds, axis=1)

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize= (5, 5))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
# Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#          all       0.96      0.95      0.96      1082
#          hem       0.91      0.93      0.92       518
#
#     accuracy                           0.95      1600
#    macro avg       0.94      0.94      0.94      1600
# weighted avg       0.95      0.95      0.95      1600

# %%
 # Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}' 

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 20/20 [==============================] - 17s 819ms/step - loss: 0.3057 - accuracy: 0.9125
# 20/20 [==============================] - 14s 692ms/step - loss: 0.4575 - accuracy: 0.8313
# 20/20 [==============================] - 38s 2s/step - loss: 0.3692 - accuracy: 0.8731
# Train Loss:  0.3057243824005127
# Train Accuracy:  0.9125000238418579
# --------------------
# Validation Loss:  0.45750752091407776
# Validation Accuracy:  0.831250011920929
# --------------------
# Test Loss:  0.36919689178466797
# Test Accuracy:  0.8731250166893005
